# %% [markdown]
# ## LOGICAL OPERATORS

# %%
#Q1. write a python program that checks if a numbers is greater than 10 and less than 50.
a=30
print(a>20 and a<60)
# Out:
# True

# %%
x=70
print(x>20 and x<60)
# Out:
# False

# %%
#Q2. print True if the age is greater than 18 or equal to 18, else False.
age=18
print(age>=18)
# Out:
# True

# %%
age=25
print(age>=30)
# Out:
# False

# %%
#Q3. Take two boolean variables a=True and b=False. print the result of a and b.
a=True
b=False
print(a and b)
print(a or b) 
print(a!=b)
print(a==b)
# Out:
# False
# True
# True
# False

# %%
#Q4. Use the operator to check if either 5>10 or 2<8.
a=(5>10 or 2<8)
print(a)
# Out:
# True

# %%
a=(5>10 and 2<8)
print(a)
# Out:
# False

# %%
#Q5. Write a program that check if a number is not divisible by 3.
x=int(input("enter a number:"))
if x%3 != 0:
    print(x,"is not divisible by 3")
else:
    print(x,"is divisible by 3")
# Out:
# enter a number: 15
# 15 is divisible by 3

# %%
#Q6. Print "Access Granted" if the password is "admin123" and length is at least 6 characters .
password="admin 123"
if password =="admin 123" and len(password)>=6:
    print("Access Granted")
else:
    print("Access Denied")
# Out:
# Access Granted

# %%
name="Madhurima Singh"
if name == "Madhurima Singh" and len(name)>=15:
    print("Access Granted")
else:
    print("Access Denied")
# Out:
# Access Granted

# %%
#Q7. Given two numbers,check if both are positive using logical operators.
a=10
b=20
if a>9 and b>10:
    print("Both numbers are positive.")
else:
    print("Both numbers are not positive.")
# Out:
# Both numbers are positive.

# %%
a=-10
b=20
if a>9 and b>10:
    print("Both numbers are positive")
else:
    print("Both numbers are not positive")
# Out:
# Both numbers are not positive

# %%
#Q8. write a python expression using not that returns True if 5!=10.
x=(5!=10)
print(x)
# Out:
# True
