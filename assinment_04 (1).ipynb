# %% [markdown]
# ## 1.CREATE A DICTIONARY AND PRINT IT.

# %%
#Q1. create a dictionary that store the name and age of a person.
person={"Name":"Aryan","Age":17}
print(person)
# Out:
# {'Name': 'Aryan', 'Age': 17}

# %%
person={"Name":"madhurima singh","Age":18,"course":"B.sc in data science"}
print(person)
# Out:
# {'Name': 'madhurima singh', 'Age': 18, 'course': 'B.sc in data science'}

# %% [markdown]
# ## 2.ACCESS A VALUE FROM A DICTIONARY.

# %%
#Q2. Given the dictionary {"Name":Bob,"Age":30}, print the age.
person={"Name":"Bob","Age":30}
print(person["Age"])
# Out:
# 30

# %%
person={"Name":"Aryan","Age":17,"Class":11}
print(person["Name"])
# Out:
# Aryan

# %% [markdown]
# ## 3.ADD A NEW KEY VALUE PAIR TO A DICTIONARY.

# %%
#Q3. Add a key "City" with value "new York"to the dictionary person.
Person={"Name":"Bob","Age":25,"Class":10}
Person["City"]="New York"
print(Person)
# Out:
# {'Name': 'Bob', 'Age': 25, 'Class': 10, 'City': 'New York'}

# %%
person={"Name":"Aryan","Age":17,"Class":11}
person["City"]="Amethi"
print(person)
# Out:
# {'Name': 'Aryan', 'Age': 17, 'Class': 11, 'City': 'Amethi'}

# %% [markdown]
# ## 4.UPDATING AN EXISTING VALUE IN A DICTIONARY.

# %%
#Q4. Change the "Age" of "Alice" to 28 in the given dictionary.
person={"Name":"Alice","Age":25,"Class":12}
person["Age"]=28
print(person)
# Out:
# {'Name': 'Alice', 'Age': 28, 'Class': 12}

# %%
person={"Name":"Aryan","Age":27,"Class":11}
person["Age"]=17
print(person)
# Out:
# {'Name': 'Aryan', 'Age': 17, 'Class': 11}

# %% [markdown]
# ## 5.DELETE A KEY FROM A DICTIONARY

# %%
#Q5. Remove the "Age" key from the dictionary.
Person={"Name":"Bob","Age":25,"Class":12}
del Person["Age"]
print(Person)
# Out:
# {'Name': 'Bob', 'Class': 12}

# %%
Person={"Name":"Aryan","Age":17,"Class":11,"Subject":"PCM"}
del Person["Subject"]
print(Person)
# Out:
# {'Name': 'Aryan', 'Age': 17, 'Class': 11}

# %% [markdown]
# ## 6.GET THE LENGTH OF DICTIONARY.

# %%
Person={"Name":"Bob","Age":25,"Class":12}
print(len(Person))
# Out:
# 3

# %%
Person={"Name":"Aryan","Age":17,"Class":11,"Subject":"PCM"}
print(len(Person))
# Out:
# 4

# %% [markdown]
# ## 7.USE GET() METHOD TO ACCESS VALUE SAFELY.

# %%
#Q7. Access the "City" key using get(), provide default a "unknow" if not present.
Person={"Name":"Alice","Age":19}
City=Person.get("City","New York")
print(City)
# Out:
# New York

# %%
Person={"Name":"Aryan singh","Age":17,"Class":11}
Subject=person.get("Subject","PCM")
print(Subject)
# Out:
# PCM

# %% [markdown]
# ## 8.COPY A DICTIONARY.

# %%
#Q8. create a copy of the dictionary person.
Person={"Name":"Aryan","Age":17,"Class":11}
copy_Person=Person.copy()
print(copy_Person)
# Out:
# {'Name': 'Aryan', 'Age': 17, 'Class': 11}

# %%
Person={"Name":"Bob","Age":25,"Class":12}
copy_Person=Person.copy()
print(copy_Person)
# Out:
# {'Name': 'Bob', 'Age': 25, 'Class': 12}
